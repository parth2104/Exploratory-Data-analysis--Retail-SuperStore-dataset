# %% [markdown]
# ## The Sparks Foundation:Task 3 - Exploratory Data Analysis on Retail Dataset

# %% [markdown]
# ### DATA SCIECNE AND BUSINESS ANALYTICS INTERN: BAROT PARTH HARISHBHAI

# %% [markdown]
# DATASET: https://bit.ly/3i4rbWl
#
# OBJECTIVE :
#
#     * Perform "Exploatory Data Analysis" on Dataset "SampleSuperStore".
#     * As a Business Manager,try to find out the weak areas where you can work to make more profit.
#     * What all business problems you can derive by exploring the data?

# %% [markdown]
# ![supermarket-interior-chilled-dry-department-54613922.jpg](attachment:supermarket-interior-chilled-dry-department-54613922.jpg)

# %% [markdown]
# ## Step 0: Importing Libraries needed to perform task

# %% [raw]
# numpy and pandas         : The Pandas module mainly works with the tabular data,
#                            whereas the NumPy module works with the numerical data.
#
# matplotlib and seaborn   : Seaborn and matplotlib is Library used for data visualization.
#                            Seaborn is a Python data visualization library based on matplotlib.
#
#
# warnings                 : To Filterout the warnings to make the analysis look more clean.

# %%
#Important library
import numpy as np                   
import pandas as pd

import seaborn as sns  

import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Step 1 : Reading the dataset

# %%
# read the dataset
data = pd.read_csv("SampleSuperstore.csv")
data.head()    # loads the first five rows of the dataset
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
data.tail()    # loads the last five rows of the dataset
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
data.shape # Returns the Dimension of the Dataset.
# Out:
# (9994, 13)

# %%
print("The Number of Rows in the Dataset is:   ",data.shape[0])
print("The Number of Columns in the Dataset is:",data.shape[1])
# Out:
# The Number of Rows in the Dataset is:    9994
# The Number of Columns in the Dataset is: 13

# %%
data.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %% [markdown]
# ### Columns Description

# %% [raw]
# 1)Ship Mode    : Explains the mode of the shipment wherein type of shipment whether first class,second class etc is mentioned.
# 2)Segment      : To which segment the product is being shipped whether it is consumer,corporate etc.
# 3)Country      : Product is shipped to which country
# 4)City         : Product is shipped to which city.
# 5)State        : Product is shipped to which state.
# 6)Postal Code  : Postal Code of the region where products need to be shipped.
# 7)Region       : Product is to be shipped in which region like east,west,north etc.
# 8)Category     : Category of the product to be shipped.
# 9)Sub-Category : Sub-Category of the category of the product to be shipped wherein we will have more precise idea of what
#                  Product
# 10)Sales       : Sales of particular product shipped at particular place.
# 11)Quantity    : Quantity of the product sold,Here we can also have the idea of SP of the Product.
# 12)Discount    : Discount given on the particular product.
# 13)Profit      : Profit Obtained of Selling of Particular Product w.r.t to Its quantity.Here we can also have idea of CP of the                  Product

# %% [markdown]
# ## Step 2 : Checking for the data's information

# %% [markdown]
# ##### 😊Data Information

# %%
#Data Information.                   # Returns the concise summary of the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# ##### 😊Statistical Information

# %%
data.describe() # Gives the statistical data for the columns of type int and float.
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# ##### 😊Number of Unique Values

# %%
data.nunique() #To display the unique values in our dataset of Retail.
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %% [markdown]
# ##### 😊Unique Values

# %%
#Unique values in Segment Column

data['Segment'].unique()    #It will show the unique values inside the column name.
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
#Unique values in Ship Mode Column
data['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
#Unique Values in Country
data['Country'].unique()
# Out:
# array(['United States'], dtype=object)

# %% [raw]
# Note: This shows this Dataset of Retail is Of United States Only.

# %%
#Unique Values in Category 
data['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
#Unique Values of Sub-Category
data['Sub-Category'].unique()
# Out:
# array(['Bookcases', 'Chairs', 'Labels', 'Tables', 'Storage',
#        'Furnishings', 'Art', 'Phones', 'Binders', 'Appliances', 'Paper',
#        'Accessories', 'Envelopes', 'Fasteners', 'Supplies', 'Machines',
#        'Copiers'], dtype=object)

# %% [markdown]
# ## Step 3: Check the Null Values/Duplicate Values in the Dataset and Remove them if Any.

# %% [markdown]
# ##### Finding number of  missing values

# %%
data.isnull().sum()   #Checking if there are any null values in the dataset and getting sum of all the null values present.
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# ###### Note: 😍  This above indicates that there is no null value present in the dataset in any of the column.

# %%
data.duplicated().sum()   #Check for all the duplicated data in our dataset.
# Out:
# 17

# %% [raw]
# keep: keep is to control how to consider duplicate value. It has only three distinct value and default is ‘first’.
#
#
# If ‘first’, it considers first value as unique and rest of the same values as duplicate.
# If ‘last’, it considers last value as unique and rest of the same values as duplicate.

# %%
data.drop_duplicates(keep ="first", inplace = True)  #Drop all the Duplicate values preset in our dataset.
                                                     #Keeping the first ,rest got removed.

# %%
#Again check for duplicates.
data.duplicated().sum()
# Out:
# 0

# %%
data.shape
# Out:
# (9977, 13)

# %% [markdown]
# ##### ✨Initial the dimension was (9994, 13), and now after removal of duplicate values we remained with dimension (9977, 13)

# %% [markdown]
# ##### ✨Therefore, 9994-9977=17 Removed Rows   (By defualt also pandas keep one row as original data and count other as duplicate.)

# %% [markdown]
# ## Step 4: Check for the irrelevent COLUMNS which are not required in our dataset for drawing particular conclusion and drop them.

# %% [markdown]
# #####  Here we have dropped Postal Code Column since it is not particulary required for drawing any conclusion given the columns city and region.

# %%
retail=data.drop(columns=["Postal Code"],axis=1) 

      #It will drop the column name "Postal Code" and as if we write inplace=True...this means it will make changes to original.
retail.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#   Region         Category Sub-Category     Sales  Quantity  Discount    Profit
# 0  South        Furniture    Bookcases  261.9600         2      0.00   41.9136
# 1  South        Furniture       Chairs  731.9400         3      0.00  219.5820
# 2   West  Office Supplies       Labels   14.6200         2      0.00    6.8714
# 3  South        Furniture       Tables  957.5775         5      0.45 -383.0310
# 4  South  Office Supplies      Storage   22.3680         2      0.20    2.5164

# %% [markdown]
# ## Step 5: Check for the relationship amongst the varibales

# %% [markdown]
# ## 😉Using correlation matrix and visulize it using the headmap to get an idea.

# %% [raw]
# CORRELATION :
#         Correlation coefficients measure the strength of the relationship between two variables. A correlation between variables         indicates that as one variable changes in value, the other variable tends to change in a specific direction.
#
#         Scatterplots are a great way to check quickly for correlation between pairs of continuous data.
#
#         Range:
#
#             Values can range from -1 to +1.
#
#             Pearson’s correlation coefficient is represented by the Greek letter rho (ρ) for the population parameter and r for             a sample statistic. This correlation coefficient is a single number that measures both the strength and direction of             the linear relationship between two continuous variables. Values can range from -1 to +1.
#
#        Direction:
#             The sign of the Pearson correlation coefficient represents the direction of the relationship.
#                 Positive coefficients indicate that when the value of one variable increases, the value of the other variable                   also tends to increase. Positive relationships produce an upward slope on a scatterplot.
#
#                 Negative coefficients represent cases when the value of one variable increases, the value of the other variable                 tends to decrease. Negative relationships produce a downward slope.

# %%
correlation=retail.corr()     #Correlation on numerical values to find out the relationship.
correlation
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200722 -0.028311  0.479067
# Quantity  0.200722  1.000000  0.008678  0.066211
# Discount -0.028311  0.008678  1.000000 -0.219662
# Profit    0.479067  0.066211 -0.219662  1.000000

# %% [raw]
# COVARIANCE:
#
# Correlation is basically a concept used to identify relationship between two numeric variables. It is not applicable for non numeric data.
#
# If you want to understand relationship between one numeric and one non numeric data you can use ANOVA
#
# If you want to understand relationship between two non numeric data, you can use chi squared test of independence.

# %% [raw]
# ✨Covariance vs. Correlation ✨
#
# Covariance and correlation both primarily assess the relationship between variables.
# The closest analogy to the relationship between them is the relationship between the variance and standard deviation.
#
# Covariance measures the total variation of two random variables from their expected values. Using covariance, we can only gauge the direction of the relationship (whether the variables tend to move in tandem or show an inverse relationship). However, it does not indicate the strength of the relationship, nor the dependency between the variables.
#
# On the other hand, correlation measures the strength of the relationship between variables. Correlation is the scaled measure of covariance. It is dimensionless. In other words, the correlation coefficient is always a pure value and not measured in any units.
#
# The relationship between the two concepts can be expressed using the formula below:

# %%
retail.cov()
# Out:
#                   Sales    Quantity   Discount        Profit
# Sales     389028.396022  278.765576  -3.645637  70057.067126
# Quantity     278.765576    4.958001   0.003990     34.565743
# Discount      -3.645637    0.003990   0.042624    -10.632751
# Profit     70057.067126   34.565743 -10.632751  54970.478824

# %% [markdown]
# ### Plot the heatmap using the correlation values.

# %%
sns.heatmap(correlation, xticklabels= correlation.columns , yticklabels=correlation.columns , annot=True)

#Using seaborn we are plotting this headmap.
#PARAMETERS: Correlation values, label on x and y axis resp. ,annot means whether we want values to be written inside the blocks.
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### Observation : Here The correlation amongst the variables is very low, so we won't rely on it and move forward with our analysis.

# %% [markdown]
# ## Step 6:Check the relationship amongst the variables using pairplot.

# %%
sns.pairplot(retail) #Show the relationship between 2 variables

# %% [markdown]
# ##### Observation: Here Also since the plot is very scattered we are not able to drive anything so we will move forward with analysis since there can be no particular conclcusion from the above plots.

# %% [markdown]
# ## Step 7: Try to examine relationship amongst the variable using the Scattered Plot.

# %%
sns.relplot(x="Quantity",y="Sales",hue="Segment",data=retail)

# %% [markdown]
# ##### Observation: Here we can have breif idea about what segment genertates more sales along with the quantity required,But lets deep dive now into our analysis,draw out some conclusion from them.

# %% [markdown]
# ### We have a few questions to answer here.

# %% [raw]
# 1.  Visualizing Segment of the Consumer buying from the SuperStore.
# 2.  Analysing the Shipment Mode Prefered by the Consumers.
# 3.  Analysing the Category of items in the SuperStore.
# 4.  Analysing the Sub-Category of items in the SuperStore.
# 5.  Analysing the Profits as per the Customer Segments in the Superstore.
# 6.  Profit and Discount Relationship using frequency plot in order to determine Discount amount Maximizing Profit.
# 7.  Overall average profit mapping with the segment given the different values of Discount.
# 8.  States where maximum Sales have occurred for the Superstore in United States.
# 9.  Identifying the Sub-Category where Maximum profit is obtained.
# 10. Plotting Profit as per the Sub-Categories.
# 11. Visualizing Shipment modes prefered According to the Category using Bar Graphs.
# 12. Overall Sales data in the US according to the sub-category in all the Segments as whole.
# 13. Visualizing Profit and Discount Relationship using line plot.

# %% [markdown]
# #### 1.  Visualizing Segment of the Consumer buying from the SuperStore.

# %%
retail['Segment'].value_counts()  #Counts the number of Particular Customer Segments Present in the Dataset.
# Out:
# Consumer       5183
# Corporate      3015
# Home Office    1779
# Name: Segment, dtype: int64

# %%
#Calculating the percentage of particular segments present in the dataset.

plt1=retail['Segment'].value_counts()/len(retail['Segment']) * 100 
plt1
# Out:
# Consumer       51.949484
# Corporate      30.219505
# Home Office    17.831011
# Name: Segment, dtype: float64

# %%
plt1.plot(kind='bar',color='green')  # It Plots the information obtaied by normalizing our segment values.
# Out:
# <AxesSubplot:>

# %%
#Pie Chart
plt1.plot(kind='pie',figsize=(6,8))
plt.legend()
plt.title('Segment')
# Out:
# Text(0.5, 1.0, 'Segment')

# %% [markdown]
# ##### Conclusion: It can be observed that more than 50% of the Customer segment is of consumers,then corporate and then home office,So the Store owner should priortize accordingly

# %% [markdown]
# #### 2.  Analysing the Shipment Mode Prefered by the Consumers.

# %%
retail['Ship Mode'].value_counts() #Counts the number of particular number of shipmment modes opted as per the dataset.
# Out:
# Standard Class    5955
# Second Class      1943
# First Class       1537
# Same Day           542
# Name: Ship Mode, dtype: int64

# %%
#Calculating the percentage of Shipment Modes.

plt2=retail['Ship Mode'].value_counts()/len(retail['Ship Mode'])*100    # len(retail['Ship Mode']) means sum of dhip mode value.
plt2
# Out:
# Standard Class    59.687281
# Second Class      19.474792
# First Class       15.405432
# Same Day           5.432495
# Name: Ship Mode, dtype: float64

# %%
plt2.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
#Pie
plt2.plot(kind='pie',figsize=(5,8))
# Out:
# <AxesSubplot:ylabel='Ship Mode'>

# %% [markdown]
# ##### Conclusion: Around more than 50% of the customers opt for the Standard Shipment and however very few customers opt for the same day shipmment.So Logistical decisions and planning can be made accordingly.

# %% [markdown]
# #### 3.  Analysing the Category of items in the SuperStore.

# %%
retail['Category'].value_counts() #Counts the number of particular number of categoroes according to the dataset.
# Out:
# Office Supplies    6012
# Furniture          2118
# Technology         1847
# Name: Category, dtype: int64

# %%
#Calculating the percentage of Categories present.

plt3=retail['Category'].value_counts()/len(retail['Category'])*100
plt3
# Out:
# Office Supplies    60.258595
# Furniture          21.228826
# Technology         18.512579
# Name: Category, dtype: float64

# %%
plt3.plot(kind='bar',color='red')
# Out:
# <AxesSubplot:>

# %%
#Pie
plt3.plot(kind='pie',figsize=(5,6))
plt3
# Out:
# Office Supplies    60.258595
# Furniture          21.228826
# Technology         18.512579
# Name: Category, dtype: float64

# %% [markdown]
# #### Conclusion:More than 60% of the products sold are in the category of office supplies,so owner need to make the inventory decisions accordingly.

# %%
retail['Sub-Category'].value_counts()  #Counts the number of particular number of sub-categories accordingly to the dataset.
# Out:
# Binders        1522
# Paper          1359
# Furnishings     956
# Phones          889
# Storage         846
# Art             795
# Accessories     775
# Chairs          615
# Appliances      466
# Labels          363
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
#Calculating the percentage of the sub categories present.

plt4=retail['Sub-Category'].value_counts()/len(retail['Sub-Category'])*100
plt4
# Out:
# Binders        15.255087
# Paper          13.621329
# Furnishings     9.582039
# Phones          8.910494
# Storage         8.479503
# Art             7.968327
# Accessories     7.767866
# Chairs          6.164178
# Appliances      4.670743
# Labels          3.638368
# Tables          3.197354
# Envelopes       2.545855
# Bookcases       2.285256
# Fasteners       2.175003
# Supplies        1.904380
# Machines        1.152651
# Copiers         0.681568
# Name: Sub-Category, dtype: float64

# %%
plt4.plot(kind='bar',color='cyan')
# Out:
# <AxesSubplot:>

# %%
#Pie
plt4.plot(kind='pie',figsize=(9,12))
plt4
# Out:
# Binders        15.255087
# Paper          13.621329
# Furnishings     9.582039
# Phones          8.910494
# Storage         8.479503
# Art             7.968327
# Accessories     7.767866
# Chairs          6.164178
# Appliances      4.670743
# Labels          3.638368
# Tables          3.197354
# Envelopes       2.545855
# Bookcases       2.285256
# Fasteners       2.175003
# Supplies        1.904380
# Machines        1.152651
# Copiers         0.681568
# Name: Sub-Category, dtype: float64

# %% [markdown]
# ##### Conclusion: Items Sold in terms of percentage along with the bars is given here, so owner needs to make the inventory decisions accordingly.

# %% [markdown]
# #### 5.  Analysing the Profits as per the Customer Segments in the Superstore.

# %%
fig,ax=plt.subplots()
colors={'Consumer':"red","Corporate":'Cyan',"Home Office":"Green"}
ax.scatter(x=retail['Sales'],y=retail['Profit'],c=retail['Segment'].apply(lambda x: colors[x]))   #Scatter plot of different 
                                                                                                  #customer segments
plt.xlabel("Sales") 
plt.ylabel("Profit")
plt.title("Sales and Profit Analysis on all the Segments")
plt.show()

# %% [markdown]
# #### Conclusion: Here we can derive from this Scatter plot that most of the profit comes from the cusumer segment, so they should focus of satisfying as many needs of consumer segment as possible.

# %% [markdown]
# #### 6.  Profit and Discount Relationship using frequency plot in order to determine Discount amount Maximizing Profit.

# %%
retail1=retail.loc[(retail['Segment']=='Consumer')&(retail['Discount']==0.1)]    #If Discount is 10%
retail1
# Out:
#            Ship Mode   Segment        Country           City     State  \
# 57       First Class  Consumer  United States           Troy  New York
# 362   Standard Class  Consumer  United States  New York City  New York
# 730      First Class  Consumer  United States      Oceanside  New York
# 980   Standard Class  Consumer  United States  New York City  New York
# 1146        Same Day  Consumer  United States        Lansing  Michigan
# 1249  Standard Class  Consumer  United States  New York City  New York
# 1701    Second Class  Consumer  United States  New York City  New York
# 1881        Same Day  Consumer  United States  New York City  New York
# 2181  Standard Class  Consumer  United States  New York City  New York
# 2432  Standard Class  Consumer  United States  New York City  New York
# 2640  Standard Class  Consumer  United States  New York City  New York
# 3314  Standard Class  Consumer  United States      Oceanside  New York
# ...

# %%
retail1['Profit'].plot.hist(bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
retail2=retail.loc[(retail['Segment']=='Consumer')&(retail['Discount']==0.2)]    #If Discount is 20%
retail2['Profit'].plot.hist(bins=50,color='green')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
retail3=retail.loc[(retail['Segment']=='Consumer')&(retail['Discount']==0.5)]    #If Discount is 50%
retail3['Profit'].plot.hist(bins=50,color='blue')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ##### Conclusion: We can easily see that on plotting profit with various values of discounts,max,profit obtained is at discount value about 10%.So Store owner can't really afford to give discount more than 10% to the consumer.

# %% [markdown]
# #### 7.  Overall average profit mapping with the segment given the different values of Discount.

# %%
retail4=retail.groupby(['Segment','Discount']).Profit.median()
retail4
# Out:
# Segment      Discount
# Consumer     0.00         16.14600
#              0.10         62.03900
#              0.15          5.12940
#              0.20          6.04330
#              0.30        -26.05620
#              0.32        -30.09800
#              0.40        -47.21360
#              0.45       -135.68145
#              0.50       -175.26000
#              0.60        -14.13230
#              0.70         -8.72760
#              0.80        -13.71750
# Corporate    0.00         16.35285
#              0.10         46.79080
#              0.15         26.27735
#              0.20          6.70680
#              0.30        -28.22400
#              0.32        -59.06060
#              0.40        -87.27495
#              0.45       -255.58750
#              0.50       -120.51300
#              0.60        -10.41960
#              0.70         -8.97960
#              0.80        -16.71300
# Home Office  0.00         15.45460
#              0.10         37.23000
# ...

# %%
retail4.plot(kind='bar',stacked=True,figsize=(10,10),ylabel='Profit')
# Out:
# <AxesSubplot:xlabel='Segment,Discount', ylabel='Profit'>

# %% [markdown]
# #### Conclusion: Here average profit in all the segments along with possible discount values is given to have a better understanding of the discount segment relation.

# %% [markdown]
# #### 8.  States where maximum Sales have occurred for the Superstore in United States.

# %%
#Seaborn Library is used to plot this figure.

plt.figure(figsize=(10,6))
states=retail['State'].value_counts()[0:20]  #Get the count of particular states mentioned in whole column and sort in descending.
sns.barplot(x=states ,y=states.index , palette='deep')
plt.title("States Instances to get a fait idea of which states have high density present in the dataset")
plt.xlabel("Number of Instances of States in the whole dataset.")
plt.ylabel("States of United States")
# Out:
# Text(0, 0.5, 'States of United States')

# %% [markdown]
# ##### Conclusion : Here the figure is self explanatory where one can determine in which states maximum products are sold and top 20 states out of them are depicated here.

# %% [markdown]
# #### 9.  Identifying the Sub-Category where Maximum profit is obtained.

# %%
#Top 10 Profit making sub-categories are shown here in the plot.

retail.groupby("Sub-Category")['Profit'].max().nlargest(10).plot.bar()
# Out:
# <AxesSubplot:xlabel='Sub-Category'>

# %% [markdown]
# ##### Conclusion: Sub-Categories like copiers,binders etc, generate more profit than others, so owner should really focus on selling and maintaining inventory of these.

# %% [markdown]
# #### 10. Plotting Profit as per the Sub-Categories.

# %%
pip install plotnine
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from plotnine import *

# %%
Profit_plot = ggplot(retail,aes(x='Sub-Category', y='Profit', fill='Sub-Category')) + geom_col() + coord_flip()
display(Profit_plot)
# Out:
# <ggplot: (113109141637)>

# %% [markdown]
# ##### Conclusion: Here Sub category wise profit is shown leadinig owners to focus and improve on the relevent areas.Here binders have reported highest profit as well as loss, However loss cannot be solely concluded because of the discounts given.Also copiers have the highest profit next to binders and has no loss.

# %% [markdown]
# ##### 11. Visualizing Shipment modes prefered According to the Category using Bar Graphs.

# %%
SM_Category=ggplot(retail,aes(x='Ship Mode',fill="Category"))+geom_bar(stat='count')
display(SM_Category)
# Out:
# <ggplot: (113113058422)>

# %% [markdown]
# ##### Conclusion: Here we can conclude that Majority of the people buying products of the category mentioned above will prefer standard class shipment mode

# %% [markdown]
# #### 12. Overall Sales data in the US according to the sub-category in all the Segments as whole.

# %%
flip_xlabels = theme(axis_text_x = element_text(angle=90, hjust=1),figure_size=(10,5),
                     axis_ticks_length_major=10,axis_ticks_length_minor=5)
(ggplot(retail, aes(x='Sub-Category', fill='Sales')) + geom_bar() + facet_wrap(['Segment']) 
+ flip_xlabels +theme(axis_text_x = element_text(size=12))+ggtitle("Sales From Every Segment Of United States of Whole Data"))
# Out:
# <ggplot: (113113747182)>

# %% [markdown]
# ##### Conclusion: Here we can get overall sales idea of all the sub categories segment wise,It can be considered as an overview of our dataset

# %% [markdown]
# #### 13. Visualizing Profit and Discount Relationship using line plot.

# %%
plt.figure(figsize=(15,9))
sns.lineplot('Discount','Profit',data=retail,label='Discount')
plt.legend()
plt.show()

# %% [markdown]
# ##### Conclusion:Profit is only posiitve till the value of discount is less than 10%.After that it won't be feasible for the owner to sell items with discount more than 10%.

# %% [markdown]
# ##### OVERALL CONCLUSION:USING THE EXPLORATORY DATA ANALYSIS TECHNIQUES, WE WERE ABLE TO MAKE SOME BUSINESS DECISIONS THAT WOULD HAVE POSITIVE IMPACT FOR THE SUPERSTORE.ALSO WE WERE ABLE TO POINT OUT DRAWBACKS IN THE CURRENT WORKING BUSINESS MODEL, WHERE THE OWNER CAN IMPROVE AND TURN IT INTO PROFITABLE VENTURE WITH GOOF CUSTOMER AND LOGISTICS BASE
